# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/MyDrive/nn/concrete_data.csv'
df=pd.read_csv(path)
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# PARTA

# %%
df_columns=df.columns
#predictors = df[df[df_columns != 'Strength']]
predictors= df.loc[:,df_columns != 'Strength']
target=df['Strength']

# %%
predictors=(predictors - predictors.mean())/(predictors.std())

# %%
predictors.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
import sklearn
from sklearn.model_selection import train_test_split
from tensorflow import keras as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(df.shape[1]-1,)))
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
print(predictors.shape)
print(target.shape)
# Out:
# (1030, 8)
# (1030,)

# %%
#X_train, X_test, y_train,y_test= train_test_split(predictors,target, test_size=0.3,random_state=42)
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=4)

# %%
model=regression_model()

# %%
model.fit(X_train,y_train,epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1s 2ms/step - loss: 1519.2262
# Epoch 2/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1501.6572
# Epoch 3/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1483.7466
# Epoch 4/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1464.7607
# Epoch 5/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1444.9141
# Epoch 6/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1424.0164
# Epoch 7/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1401.9111
# Epoch 8/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1378.2898
# Epoch 9/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1353.6779
# Epoch 10/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1327.5842
# Epoch 11/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1299.3159
# Epoch 12/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1270.8752
# Epoch 13/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1241.0868
# Epoch 14/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1209.9736
# Epoch 15/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1178.3531
# Epoch 16/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1145.6849
# Epoch 17/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1112.2493
# Epoch 18/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1078.3694
# Epoch 19/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1044.6859
# Epoch 20/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1009.7281
# Epoch 21/50
# 23/23 [==============================] - 0s 2ms/step - loss: 975.5877
# Epoch 22/50
# 23/23 [==============================] - 0s 2ms/step - loss: 940.6826
# Epoch 23/50
# 23/23 [==============================] - 0s 2ms/step - loss: 906.0217
# Epoch 24/50
# 23/23 [==============================] - 0s 2ms/step - loss: 871.9179
# Epoch 25/50
# 23/23 [==============================] - 0s 2ms/step - loss: 838.0072
# Epoch 26/50
# 23/23 [==============================] - 0s 2ms/step - loss: 804.6646
# Epoch 27/50
# 23/23 [==============================] - 0s 2ms/step - loss: 772.0064
# Epoch 28/50
# 23/23 [==============================] - 0s 2ms/step - loss: 739.6411
# Epoch 29/50
# 23/23 [==============================] - 0s 2ms/step - loss: 708.1984
# Epoch 30/50
# 23/23 [==============================] - 0s 2ms/step - loss: 677.6454
# Epoch 31/50
# 23/23 [==============================] - 0s 2ms/step - loss: 648.2476
# Epoch 32/50
# 23/23 [==============================] - 0s 2ms/step - loss: 619.4053
# Epoch 33/50
# 23/23 [==============================] - 0s 2ms/step - loss: 591.9675
# Epoch 34/50
# 23/23 [==============================] - 0s 2ms/step - loss: 565.4360
# Epoch 35/50
# 23/23 [==============================] - 0s 2ms/step - loss: 540.3163
# Epoch 36/50
# 23/23 [==============================] - 0s 2ms/step - loss: 516.0780
# Epoch 37/50
# 23/23 [==============================] - 0s 2ms/step - loss: 493.1459
# Epoch 38/50
# 23/23 [==============================] - 0s 2ms/step - loss: 470.9845
# Epoch 39/50
# 23/23 [==============================] - 0s 2ms/step - loss: 449.7936
# Epoch 40/50
# 23/23 [==============================] - 0s 2ms/step - loss: 429.7915
# Epoch 41/50
# 23/23 [==============================] - 0s 2ms/step - loss: 410.6478
# Epoch 42/50
# 23/23 [==============================] - 0s 2ms/step - loss: 392.4556
# Epoch 43/50
# 23/23 [==============================] - 0s 2ms/step - loss: 375.1820
# Epoch 44/50
# 23/23 [==============================] - 0s 2ms/step - loss: 358.6779
# Epoch 45/50
# 23/23 [==============================] - 0s 2ms/step - loss: 342.9065
# Epoch 46/50
# 23/23 [==============================] - 0s 2ms/step - loss: 328.3886
# Epoch 47/50
# 23/23 [==============================] - 0s 2ms/step - loss: 314.3795
# Epoch 48/50
# 23/23 [==============================] - 0s 3ms/step - loss: 301.4272
# Epoch 49/50
# 23/23 [==============================] - 0s 2ms/step - loss: 289.6009
# Epoch 50/50
# 23/23 [==============================] - 0s 2ms/step - loss: 278.2470

# %%
loss_val=model.evaluate(X_test,y_test)
y_pred=model.predict(X_test)
loss_val
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 301.0074
# 10/10 [==============================] - 0s 2ms/step
# 301.0074462890625

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_square_error = mean_squared_error(y_test, y_pred)
mean = np.mean(mean_square_error)
standard_deviation = np.std(mean_square_error)
print(mean, standard_deviation)
# Out:
# 301.0074318768793 0.0

# %%
total_mean_squared_errors = 50
epochs = 50
mean_squared_errors = []
for i in range(0, total_mean_squared_errors):
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=i)
    model.fit(X_train, y_train, epochs=epochs, verbose=0)
    MSE = model.evaluate(X_test, y_test, verbose=0)
    print("MSE "+str(i+1)+": "+str(MSE))
    y_pred = model.predict(X_test)
    mean_square_error = mean_squared_error(y_test, y_pred)
    mean_squared_errors.append(mean_square_error)

mean_squared_errors = np.array(mean_squared_errors)
mean = np.mean(mean_squared_errors)
standard_deviation = np.std(mean_squared_errors)

print('\n')
print("Below is the mean and standard deviation of " +str(total_mean_squared_errors) + " mean squared errors without normalized data. Total number of epochs for each training is: " +str(epochs) + "\n")
print("Mean: "+str(mean))
print("Standard Deviation: "+str(standard_deviation))
# Out:
# MSE 1: 147.96473693847656
# 10/10 [==============================] - 0s 2ms/step
# MSE 2: 140.16590881347656
# 10/10 [==============================] - 0s 2ms/step
# MSE 3: 98.18473052978516
# 10/10 [==============================] - 0s 2ms/step
# MSE 4: 92.57243347167969
# 10/10 [==============================] - 0s 2ms/step
# MSE 5: 84.5142822265625
# 10/10 [==============================] - 0s 2ms/step
# MSE 6: 87.5381088256836
# 10/10 [==============================] - 0s 2ms/step
# MSE 7: 87.57491302490234
# 10/10 [==============================] - 0s 2ms/step
# MSE 8: 69.32624816894531
# 10/10 [==============================] - 0s 2ms/step
# MSE 9: 70.88752746582031
# 10/10 [==============================] - 0s 2ms/step
# MSE 10: 56.72134780883789
# 10/10 [==============================] - 0s 3ms/step
# MSE 11: 55.39604949951172
# 10/10 [==============================] - 0s 2ms/step
# MSE 12: 51.350887298583984
# 10/10 [==============================] - 0s 2ms/step
# MSE 13: 57.61962127685547
# 10/10 [==============================] - 0s 2ms/step
# MSE 14: 53.1334114074707
# 10/10 [==============================] - 0s 2ms/step
# MSE 15: 47.37792205810547
# 10/10 [==============================] - 0s 3ms/step
# MSE 16: 40.50924301147461
# 10/10 [==============================] - 0s 3ms/step
# MSE 17: 44.96512222290039
# 10/10 [==============================] - 0s 2ms/step
# MSE 18: 43.37034606933594
# 10/10 [==============================] - 0s 2ms/step
# MSE 19: 41.53990173339844
# 10/10 [==============================] - 0s 2ms/step
# MSE 20: 44.25831985473633
# 10/10 [==============================] - 0s 2ms/step
# MSE 21: 41.77827835083008
# 10/10 [==============================] - 0s 2ms/step
# MSE 22: 41.237979888916016
# 10/10 [==============================] - 0s 3ms/step
# MSE 23: 39.215492248535156
# 10/10 [==============================] - 0s 2ms/step
# MSE 24: 41.49543380737305
# 10/10 [==============================] - 0s 2ms/step
# MSE 25: 44.03866195678711
# 10/10 [==============================] - 0s 2ms/step
# MSE 26: 42.85251235961914
# 10/10 [==============================] - 0s 2ms/step
# MSE 27: 41.423213958740234
# 10/10 [==============================] - 0s 2ms/step
# MSE 28: 40.23614501953125
# 10/10 [==============================] - 0s 2ms/step
# MSE 29: 47.01606369018555
# 10/10 [==============================] - 0s 2ms/step
# MSE 30: 44.44891357421875
# 10/10 [==============================] - 0s 2ms/step
# MSE 31: 42.00074768066406
# 10/10 [==============================] - 0s 3ms/step
# MSE 32: 39.93353271484375
# 10/10 [==============================] - 0s 2ms/step
# MSE 33: 39.93596649169922
# 10/10 [==============================] - 0s 2ms/step
# MSE 34: 43.890113830566406
# 10/10 [==============================] - 0s 2ms/step
# MSE 35: 43.09735107421875
# 10/10 [==============================] - 0s 2ms/step
# MSE 36: 47.46023178100586
# 10/10 [==============================] - 0s 3ms/step
# MSE 37: 41.40108108520508
# 10/10 [==============================] - 0s 3ms/step
# MSE 38: 46.41968536376953
# 10/10 [==============================] - 0s 2ms/step
# MSE 39: 42.44395446777344
# 10/10 [==============================] - 0s 2ms/step
# MSE 40: 39.558197021484375
# 10/10 [==============================] - 0s 2ms/step
# MSE 41: 45.31308364868164
# 10/10 [==============================] - 0s 3ms/step
# MSE 42: 38.92393493652344
# 10/10 [==============================] - 0s 3ms/step
# MSE 43: 41.85055923461914
# 10/10 [==============================] - 0s 2ms/step
# MSE 44: 46.89970779418945
# 10/10 [==============================] - 0s 2ms/step
# MSE 45: 46.37886047363281
# 10/10 [==============================] - 0s 2ms/step
# MSE 46: 45.99949264526367
# 10/10 [==============================] - 0s 2ms/step
# MSE 47: 40.84223175048828
# 10/10 [==============================] - 0s 3ms/step
# MSE 48: 43.13005065917969
# 10/10 [==============================] - 0s 2ms/step
# MSE 49: 42.98303985595703
# 10/10 [==============================] - 0s 2ms/step
# MSE 50: 46.93867492675781
# 10/10 [==============================] - 0s 2ms/step
#
#
# Below is the mean and standard deviation of 50 mean squared errors without normalized data. Total number of epochs for each training is: 50
#
# Mean: 54.082284260629
# Standard Deviation: 23.640357373641063
